# %% [markdown]
# <a href="https://colab.research.google.com/github/Bryant-Dental/raptor_functions/blob/main/raptor_functions/examples/supervised_end_to_end.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Install Libraries

# %%
# !pip install raptor_functions

# %%
# !pip install mlflow optuna Boruta pycaret awscli boto3 tsfresh

# %% [markdown]
# ### Configure AWS
# - This is necessary to use train_experiments to log results and artifacts on aws instance

# %%
# !aws configure

# %% [markdown]
# ### Import Packages

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import mlflow
from raptor_functions.supervised.prediction import load_model, make_prediction, get_model_and_features, get_prediction_features
import xgboost as xgb
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from raptor_functions.supervised.train import train_experiments
from raptor_functions.supervised.datasets import get_data
from raptor_functions.supervised.feature_extraction import get_training_features

# %% [markdown]
# ### Load Data

# %%
df = get_data('validated_breath_data')
df.head()
# Out:
#    exp_unique_id exp_name  timesteps  sensor_1  sensor_2  sensor_3  sensor_4  \
# 0              0      39A        0.0   316.594   315.854   315.735   313.180
# 1              0      39A        1.0   316.928   315.854   316.188   313.324
# 2              0      39A        2.0   315.711   316.045   315.759   313.514
# 3              0      39A        3.0   316.499   315.854   315.329   312.536
# 4              0      39A        4.0   317.048   315.568   315.520   312.679
#
#    sensor_5  sensor_6  sensor_7  sensor_8  sensor_9  sensor_10  sensor_11  \
# 0   307.498   315.926   316.188   315.854   315.711    315.424    315.591
# 1   307.331   315.997   316.499   316.093   316.141    315.281    315.257
# 2   307.403   315.950   315.926   315.950   316.188    315.114    315.233
# 3   308.095   315.854   316.403   316.093   315.973    315.162    315.711
# 4   307.188   315.926   316.451   316.355   316.594    315.353    315.353
#
#    sensor_12  sensor_13  sensor_14  sensor_15  sensor_16  sensor_17  \
# 0    315.759    103.213    103.810    103.810    105.792    111.593
# 1    315.782    103.094    103.762    103.810    106.030    111.784
# 2    315.735    103.404    103.834    103.858    105.959    111.808
# 3    315.735    103.357    104.025    104.049    106.102    111.832
# 4    315.735    103.333    103.786    103.906    105.959    111.784
#
#    sensor_18  sensor_19  sensor_20  sensor_21  sensor_22  sensor_23  \
# 0    103.571    103.404    103.213    103.142    103.786    103.404
# 1    103.452    103.524    103.333    103.357    103.882    103.357
# 2    103.524    103.285    103.189    103.309    104.001    103.452
# 3    103.571    103.404    103.237    103.476    104.073    103.380
# 4    103.595    103.476    103.357    103.428    103.929    103.357
#
#    sensor_24  humidity measurement_stage    date_exp  time_elapsed  \
# 0    103.691    52.467          baseline  20/01/2022          0.00
# 1    103.595    45.112          baseline  20/01/2022          0.25
# 2    103.643    35.637          baseline  20/01/2022          0.50
# 3    103.619    28.102          baseline  20/01/2022          0.75
# 4    103.428    26.794          baseline  20/01/2022          1.00
#
#               datetime_exp             filename result
# 0  2022-01-20 13:31:47.000  39A_13_31_00.03.txt  Covid
# 1  2022-01-20 13:31:47.250  39A_13_31_00.03.txt  Covid
# 2  2022-01-20 13:31:47.500  39A_13_31_00.03.txt  Covid
# 3  2022-01-20 13:31:47.750  39A_13_31_00.03.txt  Covid
# 4  2022-01-20 13:31:48.000  39A_13_31_00.03.txt  Covid

# %%
df['exp_unique_id'].tail()
# Out:
# 148    137
# 149    137
# 150    137
# 151    137
# 152    137
# Name: exp_unique_id, dtype: int64

# %% [markdown]
# ### Feature Engineering
# - Features extracted from each sensor array  for all cycles of experiment.
# - These include piecemeal features like mean, median, std, variance and transform features eg FFT and wavelength transform.
# - There is option to use only the raw signals or add the offset and gradient signals
# - Boruta algorithm is used to select relevant features
# - Default model for boruta is xgboost but currently does not work in google colab.
# - It is advisable to use another tree model e.g random forest

# %%
forest = RandomForestClassifier()

# %%
df = get_training_features(df, offset=True, gradient=True, tree_model=forest)
# Out:
# Extracting all features
# Feature Extraction:  20%|██        | 4/20 [00:42<01:34,  5.88s/it]

# %%
df.head()

# %%
print("hello world 2")

# %% [markdown]
# ### Model Training

# %%
train_experiments(df)

# %% [markdown]
# ### Load Model

# %%
model_uri = 's3://raptor-mlflow-data/mlartifacts/1/1a2c4d859a074573869d1add23fb6075/artifacts/Random Forest Classifier'
# loaded_model = load_model(model_uri)

# %%
# Load model as a PyFuncModel.
loaded_model = mlflow.pyfunc.load_model(model_uri)

# Load model as a Sklearn flavor.
loaded_model = mlflow.sklearn.load_model(model_uri)

# %%
# # Load model from pickle file.
# model_pickle_filepath  = 'path/to/pickle_model'

# loaded_model = load_model(model_uri)

# %% [markdown]
# ## Prediction

# %%
from raptor_functions.supervised.datasets import get_data
df = get_data('handheld_data')

# select one single experiment
df_exp = df.groupby('exp_unique_id').get_group(0)

# %%
X = df_exp.drop('result', axis=1)

# %% [markdown]
# ### Method 1

# %%
prediction_data = get_prediction_features(X, model_uri)

# %%
prediction = loaded_model.predict(prediction_data)

# %% [markdown]
# ### Method 2

# %%
pred = make_prediction(X, model_uri)
